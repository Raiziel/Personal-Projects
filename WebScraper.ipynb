# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
url = "https://github.com/raiziel"
page = requests.get(url)
soup = BeautifulSoup(page.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html data-a11y-animated-images="system" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# ...

# %%
#Find Elements by ID
Page_Element = soup.find(id="user-profile-frame")
print(Page_Element.prettify())
# Out:
# <turbo-frame data-turbo-action="advance" id="user-profile-frame">
#  <div class="position-relative" data-hpc="">
#   <div class="mt-4">
#    <div class="js-pinned-items-reorder-container">
#     <h2 class="f4 mb-2 text-normal">
#      Popular repositories
#      <svg class="spinner pinned-items-spinner js-pinned-items-spinner v-align-text-bottom ml-1 anim-rotate" data-view-component="true" fill="none" height="16" style="box-sizing: content-box; color: var(--color-icon-primary);" viewbox="0 0 16 16" width="16">
#       <circle cx="8" cy="8" r="7" stroke="currentColor" stroke-opacity="0.25" stroke-width="2" vector-effect="non-scaling-stroke">
#       </circle>
#       <path d="M15 8a7.002 7.002 0 00-7-7" stroke="currentColor" stroke-linecap="round" stroke-width="2" vector-effect="non-scaling-stroke">
#       </path>
#      </svg>
# ...

# %%
#Find Elements by HTML Class Name
Elements = Page_Element.find_all("a", class_="text-bold flex-auto min-width-0")

# %%
print(Elements)
# Out:
# [<a class="text-bold flex-auto min-width-0" href="/Raiziel/Computational-Physics-300-Python-Projects">
# <span class="repo" title="Computational-Physics-300-Python-Projects">Computational-Physics-300-Python-Projects</span>
# </a>, <a class="text-bold flex-auto min-width-0" href="/Raiziel/Experimental-Physics-Python-Projects">
# <span class="repo" title="Experimental-Physics-Python-Projects">Experimental-Physics-Python-Projects</span>
# </a>, <a class="text-bold flex-auto min-width-0" href="/Raiziel/Computational-Physics-404-Python-Projects">
# <span class="repo" title="Computational-Physics-404-Python-Projects">Computational-Physics-404-Python-Projects</span>
# </a>, <a class="text-bold flex-auto min-width-0" href="/Raiziel/C-Projects">
# <span class="repo" title="C-Projects">C-Projects</span>
# </a>, <a class="text-bold flex-auto min-width-0" href="/Raiziel/CompLinearAlgebra-MATLAB-Projects">
# ...

# %%
for Repository in Elements:
    print (Repository, end="\n"*2)
# Out:
# <a class="text-bold flex-auto min-width-0" href="/Raiziel/Computational-Physics-300-Python-Projects">
# <span class="repo" title="Computational-Physics-300-Python-Projects">Computational-Physics-300-Python-Projects</span>
# </a>
#
# <a class="text-bold flex-auto min-width-0" href="/Raiziel/Experimental-Physics-Python-Projects">
# <span class="repo" title="Experimental-Physics-Python-Projects">Experimental-Physics-Python-Projects</span>
# </a>
#
# <a class="text-bold flex-auto min-width-0" href="/Raiziel/Computational-Physics-404-Python-Projects">
# <span class="repo" title="Computational-Physics-404-Python-Projects">Computational-Physics-404-Python-Projects</span>
# </a>
#
# <a class="text-bold flex-auto min-width-0" href="/Raiziel/C-Projects">
# <span class="repo" title="C-Projects">C-Projects</span>
# </a>
#
# <a class="text-bold flex-auto min-width-0" href="/Raiziel/CompLinearAlgebra-MATLAB-Projects">
# ...

# %%
for Repo in Elements:
    title_element = Repo.find("span", class_="repo")
    print(title_element.text.strip())
    print()
# Out:
# Computational-Physics-300-Python-Projects
#
# Experimental-Physics-Python-Projects
#
# Computational-Physics-404-Python-Projects
#
# C-Projects
#
# CompLinearAlgebra-MATLAB-Projects
#
# Personal-Projects

# %%
#Function returns all link/href references on the page
def FindAllLinks(WebPage):
    for link in WebPage.find_all('a'):
        print(link.get('href'))

# %%
FindAllLinks(soup)
# Out:
# #start-of-content
# https://github.com/
# /signup?ref_cta=Sign+up&ref_loc=header+logged+out&ref_page=%2F%3Cuser-name%3E&source=header
# /features/actions
# /features/packages
# /features/security
# /features/codespaces
# /features/copilot
# /features/code-review
# /features/issues
# /features/discussions
# /features
# https://docs.github.com
# https://skills.github.com/
# https://github.blog
# /enterprise
# /team
# /enterprise/startups
# https://education.github.com
# /solutions/ci-cd/
# https://resources.github.com/devops/
# https://resources.github.com/devops/fundamentals/devsecops/
# /customer-stories
# https://resources.github.com/
# /sponsors
# /readme
# /topics
# /trending
# /collections
# /pricing
#
#
#
#
# /login?return_to=https%3A%2F%2Fgithub.com%2Fraiziel
# /signup?ref_cta=Sign+up&ref_loc=header+logged+out&ref_page=%2F%3Cuser-name%3E&source=header
# /login?return_to=https%3A%2F%2Fgithub.com%2Fraiziel
# /Raiziel
# /Raiziel?tab=repositories
# /Raiziel?tab=projects
# ...

# %%
#Function Returns all text within a page 
def GetText(WebPage):
    print(WebPage.get_text().strip())

# %%
def HTML_Find_All(WebPage):
    Tag = str(input("Enter Tag Type: "))
    return WebPage.find_all(Tag)

# %%
HTML_Find_All(soup)
# Out:
# Enter Tag Type: span
# [<span class="progress-pjax-loader Progress position-fixed width-full" data-view-component="true">
#  <span class="Progress-item progress-pjax-loader-bar left-0 top-0 color-bg-accent-emphasis" data-view-component="true" style="width: 0%;"></span>
#  </span>,
#  <span class="Progress-item progress-pjax-loader-bar left-0 top-0 color-bg-accent-emphasis" data-view-component="true" style="width: 0%;"></span>,
#  <span class="d-none">Toggle navigation</span>,
#  <span class="Button-content">
#  <span class="Button-label"><div class="HeaderMenu-toggle-bar rounded my-1"></div>
#  <div class="HeaderMenu-toggle-bar rounded my-1"></div>
#  <div class="HeaderMenu-toggle-bar rounded my-1"></div></span>
#  </span>,
#  <span class="Button-label"><div class="HeaderMenu-toggle-bar rounded my-1"></div>
#  <div class="HeaderMenu-toggle-bar rounded my-1"></div>
#  <div class="HeaderMenu-toggle-bar rounded my-1"></div></span>,
# ...
